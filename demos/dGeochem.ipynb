# %% [markdown]
# # Geochemistry: Custom Dataframe

# %% [markdown]
# ## Configuration

# %%
import sys, os 
sys.path.append("..")

from minalyze import Geochem

# %% [markdown]
# ### Read sample geochemistry data from csv

# %%
filepath = '../data/OOLDEA2_1m_intervals.csv'
this     = Geochem.read_csv( filepath )

# %% [markdown]
# ### Preview the first 5 instances of data
#
#
#
# Notes: `_mdl` is method detection level. `_2SE` is 2 standard errors. [Reference](https://www.redalyc.org/journal/339/33957447005/html/#redalyc_33957447005_ref1)

# %%
this.original = this.data

# %% [markdown]
# ### Preview the last 5 instances

# %%
this.tail()
# Out:
#         id  result_master_id DDH_name  from_m  to_m  Sample_Length_m  \
# 151  69383                38  OOLDEA2     164   165                1
# 152  69384                38  OOLDEA2     165   166                1
# 153  69385                38  OOLDEA2     166   167                1
# 154  69386                38  OOLDEA2     167   168                1
# 155  69387                38  OOLDEA2     168   169                1
#
#      Scan_Length_m  Scan_Recovery_pct  Comp(c/s)  Rayl(c/s)  LT(secs)  Al_pct  \
# 151         0.9415              94.15   1656.487   520.2108     70.32  4.8455
# 152         0.8726              87.26   1544.148   524.4318     64.57  4.9410
# 153         0.7751              77.51   1957.022   561.2939     61.08  3.0492
# 154         0.8018              80.18   1702.285   545.7176     59.02  4.8281
# 155         0.7051              70.51   1184.426   468.7084     49.69  3.1719
#
#      Al_2SE_pct  Al_mdl_pct   Si_pct  Si_2SE_pct  Si_mdl_pct     P_ppm  \
# 151      0.5438      0.3522  20.7783      0.4967      0.1446    0.0000
# 152      0.5647      0.3738  21.6125      0.5246      0.1531  719.2218
# 153      0.4626      0.4643  20.0238      0.5040      0.1675    0.0000
# 154      0.5714      0.4070  22.3099      0.5491      0.1624    0.0000
# 155      0.5133      0.5217  19.8472      0.5417      0.1944    0.0000
#
#      P_2SE_ppm  P_mdl_ppm   S_pct  S_2SE_pct  S_mdl_pct  Cl_ppm  Cl_2SE_ppm  \
# 151   370.5214   509.7397  0.0455     0.0302     0.0429       0           0
# 152   395.8338   534.1793  0.0000     0.0300     0.0454       0           0
# 153     0.0000     0.0000  0.0000     0.0312     0.0455       0           0
# 154   411.5450   570.8387  0.0000     0.0330     0.0473       0           0
# 155   454.3143   648.0852  0.0000     0.0353     0.0529       0           0
#
#      Cl_mdl_ppm   K_pct  K_2SE_pct  K_mdl_pct  Ca_pct  Ca_2SE_pct  Ca_mdl_pct  \
# 151           0  1.4626     0.0183     0.0037  0.7006      0.0080      0.0020
# 152           0  1.1669     0.0158     0.0039  0.7373      0.0085      0.0021
# 153           0  1.3971     0.0182     0.0040  2.3847      0.0212      0.0022
# 154           0  1.7658     0.0220     0.0041  1.1240      0.0118      0.0023
# 155           0  0.5799     0.0108     0.0045  0.7984      0.0096      0.0024
#
#         Ti_ppm  Ti_2SE_ppm  Ti_mdl_ppm  V_ppm  V_2SE_ppm  V_mdl_ppm  Cr_ppm  \
# 151  1944.2044     31.1744     10.1916  25.25       5.75       5.92   35.78
# 152  2099.4770     33.5724     10.7911  27.97       6.07       6.41   39.85
# 153  2527.5257     40.1670     11.3907  18.86       6.39       6.64   35.71
# 154  2199.5949     35.9705     11.3907  31.49       6.55       6.78   34.50
# 155  1946.6025     34.1720     11.9902  19.02       6.55       7.13   51.45
#
#      Cr_2SE_ppm  Cr_mdl_ppm     Mn_ppm  Mn_2SE_ppm  Mn_mdl_ppm   Fe_pct  \
# 151        5.65        7.59  4424.4728     78.9946      6.1957  13.2771
# 152        6.10        8.17  4133.2770     74.3479      6.9701  16.9608
# 153        6.18        8.50  2894.9203     53.4375      7.7446  13.5181
# 154        6.33        8.66  2326.4688     43.3696      7.7446  16.1189
# 155        7.01        9.05  2527.0532     47.2419      8.5190  21.3131
#
#      Fe_2SE_pct  Fe_mdl_pct  Ni_ppm  Ni_2SE_ppm  Ni_mdl_ppm  Cu_pct  \
# 151      0.0180      0.0008   11.70        1.45        1.96  0.0073
# 152      0.0225      0.0008   14.35        1.71        2.25  0.0049
# 153      0.0192      0.0008   19.31        1.79        2.29  0.0050
# 154      0.0220      0.0008   17.68        1.79        2.32  0.0045
# 155      0.0285      0.0010   11.45        2.05        2.77  0.0051
#
#      Cu_2SE_pct  Cu_mdl_pct  Zn_pct  Zn_2SE_pct  Zn_mdl_pct  Ga_ppm  \
# 151      0.0004      0.0006  0.0051      0.0002      0.0003   14.08
# 152      0.0005      0.0007  0.0049      0.0003      0.0003   16.09
# 153      0.0005      0.0007  0.0064      0.0003      0.0003   21.31
# 154      0.0005      0.0007  0.0042      0.0003      0.0003   18.04
# 155      0.0006      0.0008  0.0163      0.0005      0.0004    8.92
#
#      Ga_2SE_ppm  Ga_mdl_ppm  As_ppm  As_2SE_ppm  As_mdl_ppm  Se_ppm  \
# 151        1.51        2.13    6.44        2.57        3.75  0.0000
# 152        1.70        2.39   13.35        2.90        4.16  0.0005
# 153        1.76        2.48    5.95        2.90        4.42  0.0008
# 154        1.76        2.49    9.65        2.90        4.38  0.0005
# 155        2.01        2.91    6.27        3.38        5.06  0.0000
#
#      Se_2SE_ppm  Se_mdl_ppm  Rb_ppm  Rb_2SE_ppm  Rb_mdl_ppm  Sr_ppm  \
# 151      0.0002      0.0003   56.37        3.65        4.70  138.87
# 152      0.0002      0.0004   29.42        3.65        5.26  154.25
# 153      0.0003      0.0004   60.78        4.30        5.57   81.12
# 154      0.0003      0.0004   34.25        3.87        5.53  147.30
# 155      0.0003      0.0005    0.00        4.19        6.44  161.28
#
#      Sr_2SE_ppm  Sr_mdl_ppm  Y_ppm  Y_2SE_ppm  Y_mdl_ppm  Zr_ppm  Zr_2SE_ppm  \
# 151        5.73        4.11  14.53       5.58       7.85   57.29        5.34
# 152        6.43        4.59  22.11       6.53       8.75   58.36        6.01
# 153        4.52        4.87  17.59       6.63       9.38  115.12        7.08
# 154        6.34        4.81  18.64       6.63       9.22   54.76        6.28
# 155        7.21        5.60  15.48       7.37      10.56   27.78        6.94
#
#      Zr_mdl_ppm  Nb_ppm  Nb_2SE_ppm  Nb_mdl_ppm  Mo_ppm  Mo_2SE_ppm  \
# 151        7.58     0.0        0.00        0.00       0         5.9
# 152        8.42     0.0        0.00        0.00       0         6.6
# 153        9.04     0.0        6.52       10.12       0         0.0
# 154        8.87     0.0        0.00        0.00       0         6.9
# 155       10.17     0.0        7.27       11.29       0         7.9
#
#      Mo_mdl_ppm  Ba_ppm  Ba_2SE_ppm  Ba_mdl_ppm  La_ppm  La_2SE_ppm  \
# 151        8.94  336.87      103.26       43.87   58.43       33.58
# 152        9.87  218.03      102.93       47.18   68.97       35.82
# 153        0.00    0.00        0.00        0.00  114.80       41.03
# 154       10.38  245.90      112.58       49.86   79.04       38.97
# 155       11.99    0.00        0.00        0.00  116.73       38.49
#
#      La_mdl_ppm  Ce_ppm  Ce_2SE_ppm  Ce_mdl_ppm  Pb_pct  Pb_2SE_pct  \
# 151       20.11  189.02       22.34       23.80     0.0      0.0011
# 152       21.69  211.75       23.87       25.67     0.0      0.0000
# 153       22.64  117.73       25.62       26.52     0.0      0.0013
# 154       22.96  212.74       25.77       27.18     0.0      0.0013
# 155       24.10  199.32       25.92       28.52     0.0      0.0000
#
#      Pb_mdl_pct  U_ppm  U_2SE_ppm  U_mdl_ppm  \
# 151      0.0017  20.35       9.04      12.86
# 152      0.0000  19.08       9.80      14.40
# 153      0.0019  32.09      10.72      15.23
# 154      0.0019  21.36      10.30      15.11
# 155      0.0000   0.00      11.65      17.69
#
#                                         minaloggerlink
# 151  https://minalogger.com/viewer/?project=WESTERN...
# 152  https://minalogger.com/viewer/?project=WESTERN...
# 153  https://minalogger.com/viewer/?project=WESTERN...
# 154  https://minalogger.com/viewer/?project=WESTERN...
# 155  https://minalogger.com/viewer/?project=WESTERN...

# %% [markdown]
# ### Helper methods
#
# List variables

# %%
this.variables()
# Out:
# ['id',
#  'result_master_id',
#  'DDH_name',
#  'from_m',
#  'to_m',
#  'Sample_Length_m',
#  'Scan_Length_m',
#  'Scan_Recovery_pct',
#  'Comp(c/s)',
#  'Rayl(c/s)',
#  'LT(secs)',
#  'Al_pct',
#  'Al_2SE_pct',
#  'Al_mdl_pct',
#  'Si_pct',
#  'Si_2SE_pct',
#  'Si_mdl_pct',
#  'P_ppm',
#  'P_2SE_ppm',
#  'P_mdl_ppm',
#  'S_pct',
#  'S_2SE_pct',
#  'S_mdl_pct',
#  'Cl_ppm',
#  'Cl_2SE_ppm',
#  'Cl_mdl_ppm',
#  'K_pct',
#  'K_2SE_pct',
#  'K_mdl_pct',
#  'Ca_pct',
#  'Ca_2SE_pct',
#  'Ca_mdl_pct',
#  'Ti_ppm',
#  'Ti_2SE_ppm',
#  'Ti_mdl_ppm',
#  'V_ppm',
#  'V_2SE_ppm',
#  'V_mdl_ppm',
#  'Cr_ppm',
#  'Cr_2SE_ppm',
#  'Cr_mdl_ppm',
#  'Mn_ppm',
#  'Mn_2SE_ppm',
#  'Mn_mdl_ppm',
#  'Fe_pct',
#  'Fe_2SE_pct',
#  'Fe_mdl_pct',
#  'Ni_ppm',
#  'Ni_2SE_ppm',
#  'Ni_mdl_ppm',
#  'Cu_pct',
#  'Cu_2SE_pct',
#  'Cu_mdl_pct',
#  'Zn_pct',
#  'Zn_2SE_pct',
#  'Zn_mdl_pct',
#  'Ga_ppm',
#  'Ga_2SE_ppm',
#  'Ga_mdl_ppm',
#  'As_ppm',
#  'As_2SE_ppm',
#  'As_mdl_ppm',
#  'Se_ppm',
#  'Se_2SE_ppm',
#  'Se_mdl_ppm',
#  'Rb_ppm',
#  'Rb_2SE_ppm',
#  'Rb_mdl_ppm',
#  'Sr_ppm',
#  'Sr_2SE_ppm',
#  'Sr_mdl_ppm',
#  'Y_ppm',
#  'Y_2SE_ppm',
#  'Y_mdl_ppm',
#  'Zr_ppm',
#  'Zr_2SE_ppm',
#  'Zr_mdl_ppm',
#  'Nb_ppm',
#  'Nb_2SE_ppm',
#  'Nb_mdl_ppm',
#  'Mo_ppm',
#  'Mo_2SE_ppm',
#  'Mo_mdl_ppm',
#  'Ba_ppm',
#  'Ba_2SE_ppm',
#  'Ba_mdl_ppm',
#  'La_ppm',
#  'La_2SE_ppm',
#  'La_mdl_ppm',
#  'Ce_ppm',
#  'Ce_2SE_ppm',
#  'Ce_mdl_ppm',
#  'Pb_pct',
#  'Pb_2SE_pct',
#  'Pb_mdl_pct',
#  'U_ppm',
#  'U_2SE_ppm',
#  'U_mdl_ppm',
#  'minaloggerlink']

# %% [markdown]
# List features

# %%
this.features()
# Out:
# ['Si_pct',
#  'Cu_pct',
#  'K_pct',
#  'Ni_ppm',
#  'Cr_ppm',
#  'As_ppm',
#  'V_ppm',
#  'Y_ppm',
#  'Se_ppm',
#  'Ce_ppm',
#  'Mn_ppm',
#  'Al_pct',
#  'Mo_ppm',
#  'Nb_ppm',
#  'Ga_ppm',
#  'Ti_ppm',
#  'Rb_ppm',
#  'Pb_pct',
#  'P_ppm',
#  'Sr_ppm',
#  'U_ppm',
#  'La_ppm',
#  'Cl_ppm',
#  'Ca_pct',
#  'Ba_ppm',
#  'Zr_ppm',
#  'Zn_pct',
#  'S_pct',
#  'Fe_pct']

# %% [markdown]
# List all features for a specified element

# %%
this.element("Ca")
# Out:
# ['Ca_pct', 'Ca_2SE_pct', 'Ca_mdl_pct']

# %% [markdown]
# List all "ignored" features. These are variables/features not used in clustering, but retained for visualization.

# %%
this.ignore_features()
# Out:
# ['id',
#  'result_master_id',
#  'DDH_name',
#  'from_m',
#  'to_m',
#  'Sample_Length_m',
#  'Scan_Length_m',
#  'Scan_Recovery_pct',
#  'Comp(c/s)',
#  'Rayl(c/s)',
#  'LT(secs)',
#  'minaloggerlink',
#  'Al_mdl_pct',
#  'Si_mdl_pct',
#  'P_mdl_ppm',
#  'S_mdl_pct',
#  'Cl_mdl_ppm',
#  'K_mdl_pct',
#  'Ca_mdl_pct',
#  'Ti_mdl_ppm',
#  'V_mdl_ppm',
#  'Cr_mdl_ppm',
#  'Mn_mdl_ppm',
#  'Fe_mdl_pct',
#  'Ni_mdl_ppm',
#  'Cu_mdl_pct',
#  'Zn_mdl_pct',
#  'Ga_mdl_ppm',
#  'As_mdl_ppm',
#  'Se_mdl_ppm',
#  'Rb_mdl_ppm',
#  'Sr_mdl_ppm',
#  'Y_mdl_ppm',
#  'Zr_mdl_ppm',
#  'Nb_mdl_ppm',
#  'Mo_mdl_ppm',
#  'Ba_mdl_ppm',
#  'La_mdl_ppm',
#  'Ce_mdl_ppm',
#  'Pb_mdl_pct',
#  'U_mdl_ppm',
#  'Al_2SE_pct',
#  'Si_2SE_pct',
#  'P_2SE_ppm',
#  'S_2SE_pct',
#  'Cl_2SE_ppm',
#  'K_2SE_pct',
#  'Ca_2SE_pct',
#  'Ti_2SE_ppm',
#  'V_2SE_ppm',
#  'Cr_2SE_ppm',
#  'Mn_2SE_ppm',
#  'Fe_2SE_pct',
#  'Ni_2SE_ppm',
#  'Cu_2SE_pct',
#  'Zn_2SE_pct',
#  'Ga_2SE_ppm',
#  'As_2SE_ppm',
#  'Se_2SE_ppm',
#  'Rb_2SE_ppm',
#  'Sr_2SE_ppm',
#  'Y_2SE_ppm',
#  'Zr_2SE_ppm',
#  'Nb_2SE_ppm',
#  'Mo_2SE_ppm',
#  'Ba_2SE_ppm',
#  'La_2SE_ppm',
#  'Ce_2SE_ppm',
#  'Pb_2SE_pct',
#  'U_2SE_ppm']

# %% [markdown]
# ### Visualization

# %%
this.preview( "U" )

# %%
this.savefig()

# %%
this.fit_transform()

# %%
this.prepared
# Out:
# array([[26.29821011,  9.07836395, -2.17944652, ..., -1.05178977,
#         -2.39968393,  1.57258157],
#        [16.02848174,  9.11005451, -3.94469741, ...,  5.89619407,
#         -0.25882271, -1.29863063],
#        [ 8.7353035 ,  8.15434438, -2.77231561, ...,  3.47457031,
#          0.48093868,  1.03993708],
#        ...,
#        [ 2.58419027, -0.6535482 ,  3.63265918, ..., -2.59256493,
#          1.48428511, -1.02238055],
#        [ 2.67765603, -2.25575276,  0.76830011, ..., -0.7799189 ,
#         -0.75324069,  0.66112271],
#        [ 9.67042967, -7.57890053,  4.78710918, ...,  0.98378113,
#         -1.29044278, -2.07258879]])
